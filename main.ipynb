# %% [markdown]
# <div style="display: block; text-align: right; background-color: #160b39; color: #edf2ef; font-family: 'DejaVu Sans', sans-serif;">
#   <b><i>GISC401 Map-Your-Pepeha  | 2026 |
# <span style="color: #f6d746;">Z.H</span><span style="color: #f98e09;">ynd </span><span style="color: #dd513a;">999</span><span style="color: #bc3754;">555</span><span style="color: #6a176e;">33</span>
#   </i></b> &nbsp;&nbsp;&nbsp;&nbsp;
#   </div>
# <!-- I've tried to style this notebook to match the project palette — the header and footer render reliably except perhaps the typeface, but the main cell styling falls back to browser defaults depending on the environment. In any case, the PDF is where the design lives. -->

# %% [markdown]
# This notebook procedurally generates a PDF of *Te Pepeha o Zak*.
#
# All geodata is fetched at runtime from web services (LINZ WFS, GDC ArcGIS
# FeatureServer, Natural Earth, Copernicus DEM via AWS S3) — no bundled data
# files are required. Running all cells produces
# `output/GISC401-MapYourPepeha-2026-Z.Hynd.pdf`.
#
# A LINZ API key is required to fetch river and coastline data. Log in at
# [data.linz.govt.nz](https://data.linz.govt.nz), then profile → API Keys,
# or go directly to [data.linz.govt.nz/my/api](https://data.linz.govt.nz/my/api/).
# The key is free.
#
# > **Setup:** Paste your LINZ API key between the quotes in the cell below,
# > then run all cells. The key will look something like this:
# > `5v9bx05e23r54c5832n479a6b88u9b`
# >
# > See `README.md` for full environment and dependency details.

# %%
_key = ""  # ← paste your LINZ API key between the quotes

# %%
import sys
sys.path.insert(0, ".") # add the project root directory to the system path so that we can import from 'src'
from src.maps.orchestrate import run # import the 'run' function from the 'orchestrate.py' module
run(_key) # call the run function from the orchestrate module with the LINZAPI key

# %% [markdown]
# <div style="display: block; text-align: right; background-color: #160b39; color: #edf2ef; font-family: 'DejaVu Sans', sans-serif;">
#   <b><i>GISC401 Map-Your-Pepeha  | 2026 |
# <span style="color: #f6d746;">Z.H</span><span style="color: #f98e09;">ynd </span><span style="color: #dd513a;">999</span><span style="color: #bc3754;">555</span><span style="color: #6a176e;">33</span>
#   </i></b> &nbsp;&nbsp;&nbsp;&nbsp;
#   </div>
# <!-- I've tried to style this notebook to match the project palette — the header and footer render reliably except perhaps the typeface, but the main cell styling falls back to browser defaults depending on the environment. In any case, the PDF is where the design lives. -->
